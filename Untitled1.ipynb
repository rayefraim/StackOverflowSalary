# %%
import requests
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pd.set_option('max_columns',100)
df = pd.read_csv("survey_results_public.csv",dtype="object")

# %% [markdown]
# The data is taken from Stack Overflow 2018 Annual Developer Survey. The features include developers' salary, Job satisfaction, developers' background and their daily behaviour

# %%
df.head()
# Out:
#   Respondent Hobby OpenSource         Country         Student  \
# 0          1   Yes         No           Kenya              No
# 1          3   Yes        Yes  United Kingdom              No
# 2          4   Yes        Yes   United States              No
# 3          5    No         No   United States              No
# 4          7   Yes         No    South Africa  Yes, part-time
#
#            Employment                                    FormalEducation  \
# 0  Employed part-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 1  Employed full-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 2  Employed full-time                                   Associate degree
# 3  Employed full-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4  Employed full-time  Some college/university study without earning ...
#
#                                       UndergradMajor  \
# 0                          Mathematics or statistics
# ...

# %%
df.shape
# Out:
# (98855, 129)

# %% [markdown]
# The dataframe has more than 100 features and ten thousands of rows. We want to specify the findings to about Data Scientist background and career, so we will filter those features and choose max 20 features with DevType only to Data Scientist.

# %%
df["DevType"].unique()
# Out:
# array(['Full-stack developer',
#        'Database administrator;DevOps specialist;Full-stack developer;System administrator',
#        'Engineering manager;Full-stack developer', ...,
#        'Back-end developer;Data or business analyst;Data scientist or machine learning specialist;Database administrator;Designer;Desktop or enterprise applications developer;Front-end developer;Mobile developer;Student;System administrator',
#        'Back-end developer;Designer;Embedded applications or devices developer;Front-end developer;Game or graphics developer',
#        'C-suite executive (CEO, CTO, etc.);Designer;Front-end developer;Product manager'],
#       dtype=object)

# %%
dfDS = df[df["DevType"] == "Data scientist or machine learning specialist"]

# %% [markdown]
# Filtering the Dataframe to only respondents with Data Scientist profession

# %%
dfDS.head()
# Out:
#     Respondent Hobby OpenSource        Country         Student  \
# 88         132   Yes         No        Finland              No
# 126        187   Yes         No          Italy              No
# 148        230   Yes        Yes  United States              No
# 223        334   Yes        Yes        Denmark  Yes, full-time
# 347        502    No         No  United States              No
#
#              Employment                                    FormalEducation  \
# 88   Employed full-time        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 126  Employed full-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 148  Employed full-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 223  Employed part-time  Secondary school (e.g. American high school, G...
# 347  Employed full-time          Other doctoral degree (Ph.D, Ed.D., etc.)
#
#                                         UndergradMajor  \
# 88   A natural science (ex. biology, chemistry, phy...
# ...

# %%
dfDS.info(max_cols=129)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 869 entries, 88 to 97993
# Data columns (total 129 columns):
# Respondent                     869 non-null object
# Hobby                          869 non-null object
# OpenSource                     869 non-null object
# Country                        869 non-null object
# Student                        861 non-null object
# Employment                     859 non-null object
# FormalEducation                863 non-null object
# UndergradMajor                 817 non-null object
# CompanySize                    749 non-null object
# DevType                        869 non-null object
# YearsCoding                    869 non-null object
# YearsCodingProf                780 non-null object
# JobSatisfaction                711 non-null object
# CareerSatisfaction             765 non-null object
# HopeFiveYears                  761 non-null object
# JobSearchStatus                762 non-null object
# ...

# %% [markdown]
# Checking the features on the Dataframe to then choose only what matters

# %%
dfDSSorted = dfDS[["Respondent","Country","Student","Employment","FormalEducation","UndergradMajor","CompanySize","DevType","YearsCoding","JobSatisfaction","CareerSatisfaction","HopeFiveYears","WakeTime","Currency","Salary","ConvertedSalary","CurrencySymbol","Gender","Age","WakeTime"]]

# %%
dfDSSorted.head()
# Out:
#     Respondent        Country         Student          Employment  \
# 88         132        Finland              No  Employed full-time
# 126        187          Italy              No  Employed full-time
# 148        230  United States              No  Employed full-time
# 223        334        Denmark  Yes, full-time  Employed part-time
# 347        502  United States              No  Employed full-time
#
#                                        FormalEducation  \
# 88         Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 126           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 148           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 223  Secondary school (e.g. American high school, G...
# 347          Other doctoral degree (Ph.D, Ed.D., etc.)
#
#                                         UndergradMajor  \
# 88   A natural science (ex. biology, chemistry, phy...
# 126  Computer science, computer engineering, or sof...
# 148                          Mathematics or statistics
# ...

# %%
dfDSSorted.shape
# Out:
# (869, 20)

# %%
dfDSSorted.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 869 entries, 88 to 97993
# Data columns (total 23 columns):
# Respondent            869 non-null object
# Hobby                 869 non-null object
# Country               869 non-null object
# Student               861 non-null object
# Employment            859 non-null object
# FormalEducation       863 non-null object
# UndergradMajor        817 non-null object
# CompanySize           749 non-null object
# DevType               869 non-null object
# YearsCoding           869 non-null object
# JobSatisfaction       711 non-null object
# CareerSatisfaction    765 non-null object
# HopeFiveYears         761 non-null object
# WakeTime              674 non-null object
# Currency              618 non-null object
# Salary                509 non-null object
# SalaryType            485 non-null object
# ConvertedSalary       499 non-null object
# CurrencySymbol        580 non-null object
# SelfTaughtTypes       540 non-null object
# ...

# %%
# INI COBA GUA TAMBAHAIN
